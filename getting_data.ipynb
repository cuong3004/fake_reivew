# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from tokenizers import Tokenizer, models

# %%
data = pd.read_csv("fake_review/fake reviews dataset.csv")
data_cg = data[data["label"] == "CG"]
data_or = data[data["label"] == "OR"]

# %%
def splt_text(text):
    return len(text.split(" "))

# %%
data_cg['length'] = data_cg['text_'].apply(splt_text)
data_or['length'] = data_or['text_'].apply(splt_text)
# Out:
# c:\Users\duong\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Users\duong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len("Hello Would")
# Out:
# 11

# %%
data_or.head()
# Out:
#               category  rating label  \
# 55  Home_and_Kitchen_5     5.0    OR
# 56  Home_and_Kitchen_5     5.0    OR
# 57  Home_and_Kitchen_5     5.0    OR
# 58  Home_and_Kitchen_5     5.0    OR
# 59  Home_and_Kitchen_5     5.0    OR
#
#                                                 text_  length
# 55  These are just perfect, exactly what I was loo...      10
# 56  Such a great purchase can't beat it for the price      10
# 57  What can you say--- cheap and it works as inte...      10
# 58  These are so nice, sturdy, like the color choi...      10
# 59      It is nice bowl and have had a fast shipping!      10

# %%
len(data_cg[data_cg['length'] > 100])
# Out:
# 4720

# %%
plt.hist(data_or['length'],bins=50)
plt.show()

# %%
plt.hist(data_cg['length'],bins=50)
plt.show()

# %%
list(data_or["text_"])
# Out:
# ['These are just perfect, exactly what I was looking for.',
#  "Such a great purchase can't beat it for the price",
#  'What can you say--- cheap and it works as intended.',
#  'These are so nice, sturdy, like the color choices too.',
#  'It is nice bowl and have had a fast shipping!',
#  'Great cup. Will last forever. Keeps things cool / warm.',
#  'Love them, just thought they would be a bit bigger!',
#  'Excellent quality product. Perfect for my ccozinha.',
#  'This fan is really pretty and I actually use it.',
#  'Super rough, not soft wash cloths, more like bar towels',
#  'Like this little guy. Use it often. He is small.',
#  'Perfect size .easy to unfold. Topremoves for storage. Love this.',
#  'Does not do a very good job; difficult to use.',
#  'frame was beautifully crafted and looks great with my picture.',
#  'My hot cocoa is finally perfect! This product is fabulous',
#  'i bought this for a friend and he loves it.',
# ...

# %%
list_data = list(data.text_)
list_data = [len()]
# Out:
# ['Love this!  Well made, sturdy, and very comfortable.  I love it!Very pretty',
#  "love it, a great upgrade from the original.  I've had mine for a couple of years",
#  'This pillow saved my back. I love the look and feel of this pillow.',
#  'Missing information on how to use it, but it is a great product for the price!  I',
#  'Very nice set. Good quality. We have had the set for two months now and have not been',
#  'I WANTED DIFFERENT FLAVORS BUT THEY ARE NOT.',
#  'They are the perfect touch for me and the only thing I wish they had a little more space.',
#  'These done fit well and look great.  I love the smoothness of the edges and the extra',
#  "Great big numbers & easy to read, the only thing I didn't like is the size of the",
#  'My son loves this comforter and it is very well made.  We also have a baby',
#  "As advertised. 5th one I've had. The only problem is that it's not really a",
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test = train_test_split(data, test_size=0.2, random_state=42)

# %%
data_train.to_csv("fake_review_train.csv")
data_test.to_csv("fake_review_test.csv")
